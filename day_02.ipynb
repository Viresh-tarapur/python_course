# %% [markdown]
# <a href="https://colab.research.google.com/github/Viresh-tarapur/python_course/blob/main/day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **integer**

# %%
print(int("40" , 8))
# Out:
# 32

# %%
print(int("000101" , 2))
# Out:
# 5

# %%
print(int("38",16))
# Out:
# 56

# %%
print(hex(56))
# Out:
# 0x38

# %% [markdown]
# float
# 3.1  pi 3 power 2

# %%
a = 3.44

print(type(a))
# Out:
# <class 'float'>

# %%
a = 3**2
print(type(a))
# Out:
# <class 'int'>

# %%
b = -0.44
print(type(b))
# Out:
# <class 'float'>

# %%
a= 32 + 42j

print(type(a))
# Out:
# <class 'complex'>

# %%
com= 32 + 42j
com2 = 10j

print(com+com2)
# Out:
# (32+52j)

# %%
com= 34 + 5j
com2 = 10j

print(com+com2)#add
print(com *com2)#multiple
print(com -com2)#sub
print(com /com2)#division
# Out:
# (34+15j)
# (-50+340j)
# (34-5j)
# (0.5-3.4j)
# real number 34.0

# %%
com= 34 + 5j
com2 =10+ 10j

print(f" the sum of real number and img number{com.real + com2.imag}")
# Out:
#  the sum of real number and img number44.0

# %% [markdown]
# string

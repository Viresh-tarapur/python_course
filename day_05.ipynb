# %% [markdown]
# <a href="https://colab.research.google.com/github/Viresh-tarapur/python_course/blob/main/day_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "viresh"
print(a)
# Out:
# viresh

# %%
a = 'vireshh'
print(a)
# Out:
# vireshh

# %%
a = """viresh
tarapur"""
print(a)
# Out:
# viresh
# tarapur

# %%
a = None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = True + 1
print(a)
# Out:
# 2

# %%
my_list=[12,"viresh",True,None,"rcb"]
print(my_list)
print(type(my_list))
print(len(my_list))
# Out:
# [12, 'viresh', True, None, 'rcb']
# <class 'list'>
# 5

# %%
s= ("viresh",1,1+3j,"rcb",True)
print(s)
print(len(s))
print(type(s))
# Out:
# ('viresh', 1, (1+3j), 'rcb', True)
# 5
# <class 'tuple'>

# %%
dic={
    "name":"viresh",
    "age":21,
    "height":18.6
}
print(dic)
# Out:
# {'name': 'viresh', 'age': 21, 'height': 18.6}

# %% [markdown]
# operatars

# %%
a = 10
b =  20

print(a>b and a<b)# and operation
print(not(a>b and a<b)) # and with not
print(a>b or a<b)# or operation
print(not(a>b or a<b))

n = True
print(n)
# Out:
# False
# True
# True
# False
# True

# %%
name = "viresh"
last_name = "tarapur"
print(name > last_name)
# Out:
# True

# %%
a = b = c = 10
print(a,b,c)

b +=10 #parking
print(a)
print(b)
print(c)
# Out:
# 10 10 10
# 10
# 20
# 10

# %%
a= 20
b= 10

tem=a
a = b
b = tem

print(a)
print(b)
# Out:
# 10
# 20

# %%
a = 10
b = 20

a,b = b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# identify

# %%
name = "viresh"
sir_name="pradeep"
print(name is sir_name)
# Out:
# False

# %%
name = "viresh"
sir_name="viresh"
print(id(name))
print(name is sir_name)
# Out:
# 138410089461728
# True

# %%
lis=[1,2,3,4,5]

# %%
name = "viresh"
sir_name="viresh"
print(id(name))
print(name is not sir_name)
# Out:
# 138410089461728
# False

# %%
name = "viresh"
sir_name="pradeep"
print(id(name))
print(name is not sir_name)
# Out:
# 138410089461728
# True

# %%
lis = [1,3,4,5,5]
print(id(lis))
lis2 = [1,3,4,5,5]
print(id(lis2))
print(lis is not lis2)
# Out:
# 138410090249920
# 138410090249664
# True

# %% [markdown]
# memberships in ,not in

# %%
sun = "viresh"
print("v" in sun)
# Out:
# True

# %%
lsi = [1,2,3,4,5]
print(1 in lsi)
# Out:
# True

# %%
sun = "viresh"
print("v" not in sun)
# Out:
# False

# %%
lis= [1,2,3,4,5]
print(1 not in lis)
# Out:
# False

# %% [markdown]
# ternary operator is a concise, one-line shortcut for the if-else statement

# %%
a = 100
b = 30
otp = "a is bigger then b number" if a>b else "a is smaller then b"
print(otp)
# Out:
# a is bigger then b number

# %%
a = 'python'
b = "RCB"
v= a if a>b else b

# %%
a = int (input("enter the number:"))
tem = "even" if a%2==0 else "odd"
print(tem)
# Out:
# enter the number23
# odd

# %% [markdown]
# bitwise  and & or-| not xor

# %%
a = "100"
b = "100"
